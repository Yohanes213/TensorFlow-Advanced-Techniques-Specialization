# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %%
train_stats
# Out:
#     count        mean        std     min     25%     50%     75%     max
# X1  614.0    0.763371   0.106680    0.62    0.66    0.74    0.82    0.98
# X2  614.0  672.552932  88.806056  514.50  612.50  686.00  759.50  808.50
# X3  614.0  318.779316  43.098324  245.00  294.00  318.50  343.00  416.50
# X4  614.0  176.886808  45.193295  110.25  147.00  220.50  220.50  220.50
# X5  614.0    5.238599   1.751390    3.50    3.50    3.50    7.00    7.00
# X6  614.0    3.482085   1.117343    2.00    2.00    3.00    4.00    5.00
# X7  614.0    0.226629   0.131884    0.00    0.10    0.25    0.40    0.40
# X8  614.0    2.817590   1.556741    0.00    1.00    3.00    4.00    5.00

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 938us/sample - loss: 244.9960 - y1_output_loss: 118.2673 - y2_output_loss: 125.1739 - y1_output_root_mean_squared_error: 10.9169 - y2_output_root_mean_squared_error: 11.2168 - val_loss: 51.5112 - val_y1_output_loss: 14.1121 - val_y2_output_loss: 37.4198 - val_y1_output_root_mean_squared_error: 3.7750 - val_y2_output_root_mean_squared_error: 6.1041
# Epoch 2/500
# 614/614 [==============================] - 0s 143us/sample - loss: 35.9568 - y1_output_loss: 13.2722 - y2_output_loss: 22.8312 - y1_output_root_mean_squared_error: 3.6387 - y2_output_root_mean_squared_error: 4.7662 - val_loss: 19.9150 - val_y1_output_loss: 8.6560 - val_y2_output_loss: 11.1607 - val_y1_output_root_mean_squared_error: 2.9508 - val_y2_output_root_mean_squared_error: 3.3478
# Epoch 3/500
# 614/614 [==============================] - 0s 164us/sample - loss: 29.2825 - y1_output_loss: 10.6342 - y2_output_loss: 18.5018 - y1_output_root_mean_squared_error: 3.2710 - y2_output_root_mean_squared_error: 4.3108 - val_loss: 21.0207 - val_y1_output_loss: 10.0605 - val_y2_output_loss: 11.1424 - val_y1_output_root_mean_squared_error: 3.1622 - val_y2_output_root_mean_squared_error: 3.3199
# Epoch 4/500
# 614/614 [==============================] - 0s 134us/sample - loss: 24.5661 - y1_output_loss: 9.5357 - y2_output_loss: 14.8337 - y1_output_root_mean_squared_error: 3.1025 - y2_output_root_mean_squared_error: 3.8653 - val_loss: 24.1718 - val_y1_output_loss: 9.9574 - val_y2_output_loss: 14.8495 - val_y1_output_root_mean_squared_error: 3.1256 - val_y2_output_root_mean_squared_error: 3.7951
# Epoch 5/500
# 614/614 [==============================] - 0s 136us/sample - loss: 25.3734 - y1_output_loss: 10.1093 - y2_output_loss: 15.2096 - y1_output_root_mean_squared_error: 3.1770 - y2_output_root_mean_squared_error: 3.9090 - val_loss: 37.2727 - val_y1_output_loss: 13.1459 - val_y2_output_loss: 25.4332 - val_y1_output_root_mean_squared_error: 3.5767 - val_y2_output_root_mean_squared_error: 4.9477
# Epoch 6/500
# 614/614 [==============================] - 0s 134us/sample - loss: 27.4572 - y1_output_loss: 10.0243 - y2_output_loss: 17.3258 - y1_output_root_mean_squared_error: 3.1720 - y2_output_root_mean_squared_error: 4.1708 - val_loss: 20.5787 - val_y1_output_loss: 9.2704 - val_y2_output_loss: 11.1470 - val_y1_output_root_mean_squared_error: 3.0668 - val_y2_output_root_mean_squared_error: 3.3426
# Epoch 7/500
# 614/614 [==============================] - 0s 131us/sample - loss: 22.1756 - y1_output_loss: 8.6692 - y2_output_loss: 13.3438 - y1_output_root_mean_squared_error: 2.9537 - y2_output_root_mean_squared_error: 3.6676 - val_loss: 20.5033 - val_y1_output_loss: 8.0535 - val_y2_output_loss: 12.4190 - val_y1_output_root_mean_squared_error: 2.8441 - val_y2_output_root_mean_squared_error: 3.5234
# Epoch 8/500
# 614/614 [==============================] - 0s 130us/sample - loss: 20.2126 - y1_output_loss: 8.2471 - y2_output_loss: 12.0865 - y1_output_root_mean_squared_error: 2.8746 - y2_output_root_mean_squared_error: 3.4568 - val_loss: 43.5604 - val_y1_output_loss: 12.7466 - val_y2_output_loss: 32.0236 - val_y1_output_root_mean_squared_error: 3.5381 - val_y2_output_root_mean_squared_error: 5.5716
# Epoch 9/500
# 614/614 [==============================] - 0s 142us/sample - loss: 21.8630 - y1_output_loss: 8.0434 - y2_output_loss: 13.7642 - y1_output_root_mean_squared_error: 2.8463 - y2_output_root_mean_squared_error: 3.7097 - val_loss: 17.5951 - val_y1_output_loss: 7.2413 - val_y2_output_loss: 10.3541 - val_y1_output_root_mean_squared_error: 2.7050 - val_y2_output_root_mean_squared_error: 3.2059
# Epoch 10/500
# 614/614 [==============================] - 0s 135us/sample - loss: 24.5390 - y1_output_loss: 8.9219 - y2_output_loss: 15.5787 - y1_output_root_mean_squared_error: 2.9895 - y2_output_root_mean_squared_error: 3.9499 - val_loss: 18.2652 - val_y1_output_loss: 8.1604 - val_y2_output_loss: 10.6466 - val_y1_output_root_mean_squared_error: 2.8210 - val_y2_output_root_mean_squared_error: 3.2105
# Epoch 11/500
# 614/614 [==============================] - 0s 135us/sample - loss: 20.1374 - y1_output_loss: 7.6981 - y2_output_loss: 12.3239 - y1_output_root_mean_squared_error: 2.7839 - y2_output_root_mean_squared_error: 3.5195 - val_loss: 16.7036 - val_y1_output_loss: 6.9381 - val_y2_output_loss: 9.7515 - val_y1_output_root_mean_squared_error: 2.6453 - val_y2_output_root_mean_squared_error: 3.1155
# Epoch 12/500
# 614/614 [==============================] - 0s 133us/sample - loss: 19.1122 - y1_output_loss: 7.3777 - y2_output_loss: 11.6007 - y1_output_root_mean_squared_error: 2.7280 - y2_output_root_mean_squared_error: 3.4162 - val_loss: 16.0625 - val_y1_output_loss: 6.7288 - val_y2_output_loss: 9.4812 - val_y1_output_root_mean_squared_error: 2.5895 - val_y2_output_root_mean_squared_error: 3.0589
# Epoch 13/500
# 614/614 [==============================] - 0s 136us/sample - loss: 20.9358 - y1_output_loss: 8.0201 - y2_output_loss: 12.9650 - y1_output_root_mean_squared_error: 2.8381 - y2_output_root_mean_squared_error: 3.5890 - val_loss: 42.1184 - val_y1_output_loss: 12.6747 - val_y2_output_loss: 31.7320 - val_y1_output_root_mean_squared_error: 3.4729 - val_y2_output_root_mean_squared_error: 5.4825
# Epoch 14/500
# 614/614 [==============================] - 0s 128us/sample - loss: 18.0996 - y1_output_loss: 7.0670 - y2_output_loss: 11.1512 - y1_output_root_mean_squared_error: 2.6439 - y2_output_root_mean_squared_error: 3.3331 - val_loss: 19.8820 - val_y1_output_loss: 6.7434 - val_y2_output_loss: 13.3594 - val_y1_output_root_mean_squared_error: 2.5876 - val_y2_output_root_mean_squared_error: 3.6313
# Epoch 15/500
# 614/614 [==============================] - 0s 131us/sample - loss: 20.4212 - y1_output_loss: 7.8264 - y2_output_loss: 12.4663 - y1_output_root_mean_squared_error: 2.8073 - y2_output_root_mean_squared_error: 3.5413 - val_loss: 21.0574 - val_y1_output_loss: 8.3732 - val_y2_output_loss: 13.3007 - val_y1_output_root_mean_squared_error: 2.8700 - val_y2_output_root_mean_squared_error: 3.5806
# Epoch 16/500
# 614/614 [==============================] - 0s 137us/sample - loss: 17.1621 - y1_output_loss: 6.7910 - y2_output_loss: 10.6571 - y1_output_root_mean_squared_error: 2.5946 - y2_output_root_mean_squared_error: 3.2296 - val_loss: 23.1741 - val_y1_output_loss: 6.6796 - val_y2_output_loss: 16.7957 - val_y1_output_root_mean_squared_error: 2.5861 - val_y2_output_root_mean_squared_error: 4.0603
# Epoch 17/500
# 614/614 [==============================] - 0s 152us/sample - loss: 16.4507 - y1_output_loss: 6.4547 - y2_output_loss: 10.0498 - y1_output_root_mean_squared_error: 2.5339 - y2_output_root_mean_squared_error: 3.1671 - val_loss: 28.5282 - val_y1_output_loss: 8.5524 - val_y2_output_loss: 20.5849 - val_y1_output_root_mean_squared_error: 2.9049 - val_y2_output_root_mean_squared_error: 4.4822
# Epoch 18/500
# 614/614 [==============================] - 0s 135us/sample - loss: 14.5020 - y1_output_loss: 5.7908 - y2_output_loss: 8.6135 - y1_output_root_mean_squared_error: 2.4168 - y2_output_root_mean_squared_error: 2.9429 - val_loss: 13.6232 - val_y1_output_loss: 5.9393 - val_y2_output_loss: 7.8931 - val_y1_output_root_mean_squared_error: 2.4367 - val_y2_output_root_mean_squared_error: 2.7723
# Epoch 19/500
# 614/614 [==============================] - 0s 139us/sample - loss: 13.9655 - y1_output_loss: 5.7201 - y2_output_loss: 8.3789 - y1_output_root_mean_squared_error: 2.3744 - y2_output_root_mean_squared_error: 2.8858 - val_loss: 45.9278 - val_y1_output_loss: 10.9062 - val_y2_output_loss: 36.3422 - val_y1_output_root_mean_squared_error: 3.2566 - val_y2_output_root_mean_squared_error: 5.9433
# Epoch 20/500
# 614/614 [==============================] - 0s 135us/sample - loss: 15.3364 - y1_output_loss: 5.6017 - y2_output_loss: 9.6609 - y1_output_root_mean_squared_error: 2.3730 - y2_output_root_mean_squared_error: 3.1153 - val_loss: 16.5409 - val_y1_output_loss: 7.3506 - val_y2_output_loss: 9.8923 - val_y1_output_root_mean_squared_error: 2.6733 - val_y2_output_root_mean_squared_error: 3.0650
# Epoch 21/500
# 614/614 [==============================] - 0s 139us/sample - loss: 14.4310 - y1_output_loss: 5.3855 - y2_output_loss: 9.5427 - y1_output_root_mean_squared_error: 2.3052 - y2_output_root_mean_squared_error: 3.0194 - val_loss: 80.8834 - val_y1_output_loss: 20.3687 - val_y2_output_loss: 63.9739 - val_y1_output_root_mean_squared_error: 4.4138 - val_y2_output_root_mean_squared_error: 7.8359
# Epoch 22/500
# 614/614 [==============================] - 0s 141us/sample - loss: 17.0578 - y1_output_loss: 5.9120 - y2_output_loss: 11.0674 - y1_output_root_mean_squared_error: 2.4412 - y2_output_root_mean_squared_error: 3.3314 - val_loss: 14.7822 - val_y1_output_loss: 6.2861 - val_y2_output_loss: 9.2042 - val_y1_output_root_mean_squared_error: 2.4678 - val_y2_output_root_mean_squared_error: 2.9482
# Epoch 23/500
# 614/614 [==============================] - 0s 136us/sample - loss: 12.7081 - y1_output_loss: 4.9635 - y2_output_loss: 7.7669 - y1_output_root_mean_squared_error: 2.2158 - y2_output_root_mean_squared_error: 2.7925 - val_loss: 14.1118 - val_y1_output_loss: 5.6332 - val_y2_output_loss: 8.7830 - val_y1_output_root_mean_squared_error: 2.3625 - val_y2_output_root_mean_squared_error: 2.9207
# Epoch 24/500
# 614/614 [==============================] - 0s 133us/sample - loss: 13.5881 - y1_output_loss: 4.7648 - y2_output_loss: 8.7103 - y1_output_root_mean_squared_error: 2.1926 - y2_output_root_mean_squared_error: 2.9632 - val_loss: 12.9250 - val_y1_output_loss: 5.6059 - val_y2_output_loss: 7.7389 - val_y1_output_root_mean_squared_error: 2.3512 - val_y2_output_root_mean_squared_error: 2.7197
# Epoch 25/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.5027 - y1_output_loss: 4.3797 - y2_output_loss: 7.0297 - y1_output_root_mean_squared_error: 2.1011 - y2_output_root_mean_squared_error: 2.6624 - val_loss: 12.0494 - val_y1_output_loss: 4.8203 - val_y2_output_loss: 7.6694 - val_y1_output_root_mean_squared_error: 2.1707 - val_y2_output_root_mean_squared_error: 2.7088
# Epoch 26/500
# 614/614 [==============================] - 0s 144us/sample - loss: 12.7871 - y1_output_loss: 4.7232 - y2_output_loss: 7.9482 - y1_output_root_mean_squared_error: 2.1831 - y2_output_root_mean_squared_error: 2.8322 - val_loss: 11.5671 - val_y1_output_loss: 5.2167 - val_y2_output_loss: 6.7752 - val_y1_output_root_mean_squared_error: 2.2639 - val_y2_output_root_mean_squared_error: 2.5381
# Epoch 27/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.8630 - y1_output_loss: 4.4387 - y2_output_loss: 7.3213 - y1_output_root_mean_squared_error: 2.1160 - y2_output_root_mean_squared_error: 2.7176 - val_loss: 11.7393 - val_y1_output_loss: 4.4016 - val_y2_output_loss: 7.7588 - val_y1_output_root_mean_squared_error: 2.0828 - val_y2_output_root_mean_squared_error: 2.7205
# Epoch 28/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.0402 - y1_output_loss: 4.7407 - y2_output_loss: 7.4931 - y1_output_root_mean_squared_error: 2.1421 - y2_output_root_mean_squared_error: 2.7298 - val_loss: 17.3678 - val_y1_output_loss: 6.9146 - val_y2_output_loss: 11.0146 - val_y1_output_root_mean_squared_error: 2.5988 - val_y2_output_root_mean_squared_error: 3.2579
# Epoch 29/500
# 614/614 [==============================] - 0s 134us/sample - loss: 10.7901 - y1_output_loss: 4.1082 - y2_output_loss: 6.8124 - y1_output_root_mean_squared_error: 2.0186 - y2_output_root_mean_squared_error: 2.5914 - val_loss: 48.1261 - val_y1_output_loss: 11.1224 - val_y2_output_loss: 38.9076 - val_y1_output_root_mean_squared_error: 3.2617 - val_y2_output_root_mean_squared_error: 6.1227
# Epoch 30/500
# 614/614 [==============================] - 0s 132us/sample - loss: 12.6123 - y1_output_loss: 4.1611 - y2_output_loss: 8.4101 - y1_output_root_mean_squared_error: 2.0494 - y2_output_root_mean_squared_error: 2.9004 - val_loss: 13.1247 - val_y1_output_loss: 5.0059 - val_y2_output_loss: 8.5125 - val_y1_output_root_mean_squared_error: 2.2192 - val_y2_output_root_mean_squared_error: 2.8635
# Epoch 31/500
# 614/614 [==============================] - 0s 133us/sample - loss: 11.4764 - y1_output_loss: 4.1079 - y2_output_loss: 7.2614 - y1_output_root_mean_squared_error: 2.0361 - y2_output_root_mean_squared_error: 2.7075 - val_loss: 10.4355 - val_y1_output_loss: 4.5338 - val_y2_output_loss: 6.2609 - val_y1_output_root_mean_squared_error: 2.1088 - val_y2_output_root_mean_squared_error: 2.4471
# Epoch 32/500
# 614/614 [==============================] - 0s 128us/sample - loss: 9.2770 - y1_output_loss: 3.6104 - y2_output_loss: 5.6120 - y1_output_root_mean_squared_error: 1.9070 - y2_output_root_mean_squared_error: 2.3749 - val_loss: 12.4786 - val_y1_output_loss: 6.0431 - val_y2_output_loss: 6.8352 - val_y1_output_root_mean_squared_error: 2.4396 - val_y2_output_root_mean_squared_error: 2.5548
# Epoch 33/500
# 614/614 [==============================] - 0s 144us/sample - loss: 10.5307 - y1_output_loss: 3.5293 - y2_output_loss: 6.9186 - y1_output_root_mean_squared_error: 1.8875 - y2_output_root_mean_squared_error: 2.6397 - val_loss: 15.5397 - val_y1_output_loss: 5.3049 - val_y2_output_loss: 10.9546 - val_y1_output_root_mean_squared_error: 2.2614 - val_y2_output_root_mean_squared_error: 3.2289
# Epoch 34/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.3403 - y1_output_loss: 3.7945 - y2_output_loss: 6.5430 - y1_output_root_mean_squared_error: 1.9483 - y2_output_root_mean_squared_error: 2.5582 - val_loss: 14.3671 - val_y1_output_loss: 5.8722 - val_y2_output_loss: 9.1938 - val_y1_output_root_mean_squared_error: 2.3819 - val_y2_output_root_mean_squared_error: 2.9485
# Epoch 35/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.9299 - y1_output_loss: 3.5479 - y2_output_loss: 6.3052 - y1_output_root_mean_squared_error: 1.8894 - y2_output_root_mean_squared_error: 2.5219 - val_loss: 9.2986 - val_y1_output_loss: 3.7441 - val_y2_output_loss: 5.9736 - val_y1_output_root_mean_squared_error: 1.9103 - val_y2_output_root_mean_squared_error: 2.3768
# Epoch 36/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.0885 - y1_output_loss: 3.4522 - y2_output_loss: 6.6246 - y1_output_root_mean_squared_error: 1.8642 - y2_output_root_mean_squared_error: 2.5716 - val_loss: 11.9251 - val_y1_output_loss: 5.9660 - val_y2_output_loss: 6.3400 - val_y1_output_root_mean_squared_error: 2.4241 - val_y2_output_root_mean_squared_error: 2.4595
# Epoch 37/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.5424 - y1_output_loss: 3.2733 - y2_output_loss: 6.1997 - y1_output_root_mean_squared_error: 1.8142 - y2_output_root_mean_squared_error: 2.5002 - val_loss: 8.8727 - val_y1_output_loss: 3.7019 - val_y2_output_loss: 5.6620 - val_y1_output_root_mean_squared_error: 1.8840 - val_y2_output_root_mean_squared_error: 2.3073
# Epoch 38/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.2848 - y1_output_loss: 3.0751 - y2_output_loss: 5.1345 - y1_output_root_mean_squared_error: 1.7617 - y2_output_root_mean_squared_error: 2.2762 - val_loss: 11.0580 - val_y1_output_loss: 3.9061 - val_y2_output_loss: 7.8785 - val_y1_output_root_mean_squared_error: 1.9246 - val_y2_output_root_mean_squared_error: 2.7118
# Epoch 39/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.5126 - y1_output_loss: 2.9308 - y2_output_loss: 4.5218 - y1_output_root_mean_squared_error: 1.7193 - y2_output_root_mean_squared_error: 2.1346 - val_loss: 15.6881 - val_y1_output_loss: 5.7906 - val_y2_output_loss: 10.3788 - val_y1_output_root_mean_squared_error: 2.3846 - val_y2_output_root_mean_squared_error: 3.1626
# Epoch 40/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.6005 - y1_output_loss: 3.4654 - y2_output_loss: 6.3049 - y1_output_root_mean_squared_error: 1.8548 - y2_output_root_mean_squared_error: 2.4820 - val_loss: 35.5222 - val_y1_output_loss: 10.2815 - val_y2_output_loss: 26.6027 - val_y1_output_root_mean_squared_error: 3.1428 - val_y2_output_root_mean_squared_error: 5.0641
# Epoch 41/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.3821 - y1_output_loss: 2.8081 - y2_output_loss: 4.5098 - y1_output_root_mean_squared_error: 1.6832 - y2_output_root_mean_squared_error: 2.1328 - val_loss: 8.6028 - val_y1_output_loss: 3.4811 - val_y2_output_loss: 5.3879 - val_y1_output_root_mean_squared_error: 1.8530 - val_y2_output_root_mean_squared_error: 2.2735
# Epoch 42/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.4201 - y1_output_loss: 3.0160 - y2_output_loss: 5.3639 - y1_output_root_mean_squared_error: 1.7409 - y2_output_root_mean_squared_error: 2.3215 - val_loss: 10.6503 - val_y1_output_loss: 3.4794 - val_y2_output_loss: 7.7317 - val_y1_output_root_mean_squared_error: 1.8218 - val_y2_output_root_mean_squared_error: 2.7076
# Epoch 43/500
# 614/614 [==============================] - 0s 136us/sample - loss: 9.6013 - y1_output_loss: 3.2257 - y2_output_loss: 6.3025 - y1_output_root_mean_squared_error: 1.8045 - y2_output_root_mean_squared_error: 2.5190 - val_loss: 18.4198 - val_y1_output_loss: 5.6834 - val_y2_output_loss: 13.2615 - val_y1_output_root_mean_squared_error: 2.3637 - val_y2_output_root_mean_squared_error: 3.5823
# Epoch 44/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.9810 - y1_output_loss: 3.1221 - y2_output_loss: 5.8612 - y1_output_root_mean_squared_error: 1.7660 - y2_output_root_mean_squared_error: 2.4212 - val_loss: 7.6794 - val_y1_output_loss: 2.8833 - val_y2_output_loss: 5.0367 - val_y1_output_root_mean_squared_error: 1.6846 - val_y2_output_root_mean_squared_error: 2.2004
# Epoch 45/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.4970 - y1_output_loss: 2.9477 - y2_output_loss: 5.4961 - y1_output_root_mean_squared_error: 1.7198 - y2_output_root_mean_squared_error: 2.3535 - val_loss: 8.2051 - val_y1_output_loss: 3.5264 - val_y2_output_loss: 4.9539 - val_y1_output_root_mean_squared_error: 1.8635 - val_y2_output_root_mean_squared_error: 2.1754
# Epoch 46/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.5213 - y1_output_loss: 2.5909 - y2_output_loss: 4.8670 - y1_output_root_mean_squared_error: 1.6172 - y2_output_root_mean_squared_error: 2.2149 - val_loss: 7.6027 - val_y1_output_loss: 2.7247 - val_y2_output_loss: 5.1735 - val_y1_output_root_mean_squared_error: 1.6315 - val_y2_output_root_mean_squared_error: 2.2228
# Epoch 47/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.8730 - y1_output_loss: 2.6688 - y2_output_loss: 5.1495 - y1_output_root_mean_squared_error: 1.6376 - y2_output_root_mean_squared_error: 2.2785 - val_loss: 8.8733 - val_y1_output_loss: 2.8793 - val_y2_output_loss: 6.3739 - val_y1_output_root_mean_squared_error: 1.6705 - val_y2_output_root_mean_squared_error: 2.4663
# Epoch 48/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.4008 - y1_output_loss: 2.4374 - y2_output_loss: 4.9155 - y1_output_root_mean_squared_error: 1.5680 - y2_output_root_mean_squared_error: 2.2231 - val_loss: 13.4318 - val_y1_output_loss: 3.9020 - val_y2_output_loss: 10.2449 - val_y1_output_root_mean_squared_error: 1.9318 - val_y2_output_root_mean_squared_error: 3.1145
# Epoch 49/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.6454 - y1_output_loss: 2.2179 - y2_output_loss: 4.3923 - y1_output_root_mean_squared_error: 1.4902 - y2_output_root_mean_squared_error: 2.1035 - val_loss: 9.0071 - val_y1_output_loss: 3.2498 - val_y2_output_loss: 6.2373 - val_y1_output_root_mean_squared_error: 1.7591 - val_y2_output_root_mean_squared_error: 2.4316
# Epoch 50/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.9927 - y1_output_loss: 2.8348 - y2_output_loss: 5.0960 - y1_output_root_mean_squared_error: 1.6907 - y2_output_root_mean_squared_error: 2.2659 - val_loss: 7.7679 - val_y1_output_loss: 2.9560 - val_y2_output_loss: 5.1204 - val_y1_output_root_mean_squared_error: 1.7030 - val_y2_output_root_mean_squared_error: 2.2062
# Epoch 51/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.6764 - y1_output_loss: 2.3043 - y2_output_loss: 4.3571 - y1_output_root_mean_squared_error: 1.5243 - y2_output_root_mean_squared_error: 2.0863 - val_loss: 9.5379 - val_y1_output_loss: 2.2657 - val_y2_output_loss: 7.6130 - val_y1_output_root_mean_squared_error: 1.4892 - val_y2_output_root_mean_squared_error: 2.7056
# Epoch 52/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.2310 - y1_output_loss: 2.2694 - y2_output_loss: 4.9019 - y1_output_root_mean_squared_error: 1.5121 - y2_output_root_mean_squared_error: 2.2236 - val_loss: 6.5338 - val_y1_output_loss: 2.4502 - val_y2_output_loss: 4.2866 - val_y1_output_root_mean_squared_error: 1.5608 - val_y2_output_root_mean_squared_error: 2.0243
# Epoch 53/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.8276 - y1_output_loss: 2.1475 - y2_output_loss: 4.7097 - y1_output_root_mean_squared_error: 1.4591 - y2_output_root_mean_squared_error: 2.1676 - val_loss: 13.0792 - val_y1_output_loss: 3.0921 - val_y2_output_loss: 10.3504 - val_y1_output_root_mean_squared_error: 1.7408 - val_y2_output_root_mean_squared_error: 3.1700
# Epoch 54/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.5383 - y1_output_loss: 2.1987 - y2_output_loss: 5.2903 - y1_output_root_mean_squared_error: 1.4870 - y2_output_root_mean_squared_error: 2.3081 - val_loss: 6.9797 - val_y1_output_loss: 2.1676 - val_y2_output_loss: 4.9968 - val_y1_output_root_mean_squared_error: 1.4743 - val_y2_output_root_mean_squared_error: 2.1923
# Epoch 55/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.6495 - y1_output_loss: 1.9520 - y2_output_loss: 4.7927 - y1_output_root_mean_squared_error: 1.4025 - y2_output_root_mean_squared_error: 2.1639 - val_loss: 17.7349 - val_y1_output_loss: 2.8670 - val_y2_output_loss: 15.4174 - val_y1_output_root_mean_squared_error: 1.6773 - val_y2_output_root_mean_squared_error: 3.8628
# Epoch 56/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.1797 - y1_output_loss: 2.4585 - y2_output_loss: 5.6938 - y1_output_root_mean_squared_error: 1.5621 - y2_output_root_mean_squared_error: 2.3958 - val_loss: 7.4179 - val_y1_output_loss: 2.9525 - val_y2_output_loss: 4.7090 - val_y1_output_root_mean_squared_error: 1.7076 - val_y2_output_root_mean_squared_error: 2.1218
# Epoch 57/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.3205 - y1_output_loss: 2.2562 - y2_output_loss: 5.0195 - y1_output_root_mean_squared_error: 1.5070 - y2_output_root_mean_squared_error: 2.2471 - val_loss: 7.2830 - val_y1_output_loss: 2.6707 - val_y2_output_loss: 4.9484 - val_y1_output_root_mean_squared_error: 1.6075 - val_y2_output_root_mean_squared_error: 2.1677
# Epoch 58/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.4551 - y1_output_loss: 2.2072 - y2_output_loss: 4.1944 - y1_output_root_mean_squared_error: 1.4923 - y2_output_root_mean_squared_error: 2.0562 - val_loss: 6.5032 - val_y1_output_loss: 2.3902 - val_y2_output_loss: 4.3586 - val_y1_output_root_mean_squared_error: 1.5220 - val_y2_output_root_mean_squared_error: 2.0461
# Epoch 59/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.8343 - y1_output_loss: 2.5547 - y2_output_loss: 5.2735 - y1_output_root_mean_squared_error: 1.5954 - y2_output_root_mean_squared_error: 2.2998 - val_loss: 5.6698 - val_y1_output_loss: 1.9034 - val_y2_output_loss: 3.8800 - val_y1_output_root_mean_squared_error: 1.3807 - val_y2_output_root_mean_squared_error: 1.9400
# Epoch 60/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.0503 - y1_output_loss: 1.9518 - y2_output_loss: 4.0465 - y1_output_root_mean_squared_error: 1.4022 - y2_output_root_mean_squared_error: 2.0209 - val_loss: 5.9025 - val_y1_output_loss: 2.1281 - val_y2_output_loss: 4.0043 - val_y1_output_root_mean_squared_error: 1.4442 - val_y2_output_root_mean_squared_error: 1.9536
# Epoch 61/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.6611 - y1_output_loss: 1.7408 - y2_output_loss: 3.9142 - y1_output_root_mean_squared_error: 1.3254 - y2_output_root_mean_squared_error: 1.9760 - val_loss: 10.1284 - val_y1_output_loss: 2.7539 - val_y2_output_loss: 7.5239 - val_y1_output_root_mean_squared_error: 1.6617 - val_y2_output_root_mean_squared_error: 2.7143
# Epoch 62/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.7970 - y1_output_loss: 2.0102 - y2_output_loss: 4.7333 - y1_output_root_mean_squared_error: 1.4208 - y2_output_root_mean_squared_error: 2.1859 - val_loss: 5.6147 - val_y1_output_loss: 2.0894 - val_y2_output_loss: 3.6929 - val_y1_output_root_mean_squared_error: 1.4445 - val_y2_output_root_mean_squared_error: 1.8783
# Epoch 63/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.2014 - y1_output_loss: 1.9203 - y2_output_loss: 4.2462 - y1_output_root_mean_squared_error: 1.3893 - y2_output_root_mean_squared_error: 2.0667 - val_loss: 6.9406 - val_y1_output_loss: 3.0530 - val_y2_output_loss: 3.9535 - val_y1_output_root_mean_squared_error: 1.7568 - val_y2_output_root_mean_squared_error: 1.9632
# Epoch 64/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.2267 - y1_output_loss: 2.0279 - y2_output_loss: 4.1778 - y1_output_root_mean_squared_error: 1.4282 - y2_output_root_mean_squared_error: 2.0462 - val_loss: 7.6063 - val_y1_output_loss: 2.4413 - val_y2_output_loss: 5.3313 - val_y1_output_root_mean_squared_error: 1.5541 - val_y2_output_root_mean_squared_error: 2.2784
# Epoch 65/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.6081 - y1_output_loss: 1.7982 - y2_output_loss: 3.7802 - y1_output_root_mean_squared_error: 1.3400 - y2_output_root_mean_squared_error: 1.9526 - val_loss: 13.1498 - val_y1_output_loss: 5.2650 - val_y2_output_loss: 8.4426 - val_y1_output_root_mean_squared_error: 2.2606 - val_y2_output_root_mean_squared_error: 2.8354
# Epoch 66/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.3207 - y1_output_loss: 1.9688 - y2_output_loss: 4.3830 - y1_output_root_mean_squared_error: 1.3900 - y2_output_root_mean_squared_error: 2.0949 - val_loss: 6.0800 - val_y1_output_loss: 2.3397 - val_y2_output_loss: 3.9918 - val_y1_output_root_mean_squared_error: 1.5035 - val_y2_output_root_mean_squared_error: 1.9543
# Epoch 67/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.9912 - y1_output_loss: 1.7693 - y2_output_loss: 3.2252 - y1_output_root_mean_squared_error: 1.3331 - y2_output_root_mean_squared_error: 1.7928 - val_loss: 7.2325 - val_y1_output_loss: 1.8323 - val_y2_output_loss: 5.6247 - val_y1_output_root_mean_squared_error: 1.3425 - val_y2_output_root_mean_squared_error: 2.3303
# Epoch 68/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.2980 - y1_output_loss: 1.7655 - y2_output_loss: 3.5422 - y1_output_root_mean_squared_error: 1.3287 - y2_output_root_mean_squared_error: 1.8795 - val_loss: 5.0218 - val_y1_output_loss: 1.6599 - val_y2_output_loss: 3.4886 - val_y1_output_root_mean_squared_error: 1.2823 - val_y2_output_root_mean_squared_error: 1.8378
# Epoch 69/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.2271 - y1_output_loss: 1.6659 - y2_output_loss: 3.5370 - y1_output_root_mean_squared_error: 1.2954 - y2_output_root_mean_squared_error: 1.8839 - val_loss: 5.3359 - val_y1_output_loss: 2.0438 - val_y2_output_loss: 3.3593 - val_y1_output_root_mean_squared_error: 1.4371 - val_y2_output_root_mean_squared_error: 1.8085
# Epoch 70/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.4156 - y1_output_loss: 1.4442 - y2_output_loss: 2.9562 - y1_output_root_mean_squared_error: 1.2062 - y2_output_root_mean_squared_error: 1.7206 - val_loss: 5.8140 - val_y1_output_loss: 2.0032 - val_y2_output_loss: 4.0078 - val_y1_output_root_mean_squared_error: 1.4033 - val_y2_output_root_mean_squared_error: 1.9608
# Epoch 71/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.7457 - y1_output_loss: 1.3585 - y2_output_loss: 3.4137 - y1_output_root_mean_squared_error: 1.1658 - y2_output_root_mean_squared_error: 1.8402 - val_loss: 13.4257 - val_y1_output_loss: 3.8171 - val_y2_output_loss: 10.2121 - val_y1_output_root_mean_squared_error: 1.9027 - val_y2_output_root_mean_squared_error: 3.1314
# Epoch 72/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.1808 - y1_output_loss: 1.2529 - y2_output_loss: 2.9225 - y1_output_root_mean_squared_error: 1.1219 - y2_output_root_mean_squared_error: 1.7094 - val_loss: 7.0771 - val_y1_output_loss: 2.2189 - val_y2_output_loss: 5.0670 - val_y1_output_root_mean_squared_error: 1.4812 - val_y2_output_root_mean_squared_error: 2.2098
# Epoch 73/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.3573 - y1_output_loss: 1.4563 - y2_output_loss: 2.9161 - y1_output_root_mean_squared_error: 1.2077 - y2_output_root_mean_squared_error: 1.7026 - val_loss: 7.0419 - val_y1_output_loss: 2.5126 - val_y2_output_loss: 4.6151 - val_y1_output_root_mean_squared_error: 1.5919 - val_y2_output_root_mean_squared_error: 2.1232
# Epoch 74/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.8222 - y1_output_loss: 1.7409 - y2_output_loss: 4.0362 - y1_output_root_mean_squared_error: 1.3237 - y2_output_root_mean_squared_error: 2.0174 - val_loss: 7.9127 - val_y1_output_loss: 3.6833 - val_y2_output_loss: 4.4155 - val_y1_output_root_mean_squared_error: 1.9133 - val_y2_output_root_mean_squared_error: 2.0620
# Epoch 75/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.1132 - y1_output_loss: 1.6202 - y2_output_loss: 3.4505 - y1_output_root_mean_squared_error: 1.2785 - y2_output_root_mean_squared_error: 1.8651 - val_loss: 4.4618 - val_y1_output_loss: 1.3372 - val_y2_output_loss: 3.2974 - val_y1_output_root_mean_squared_error: 1.1495 - val_y2_output_root_mean_squared_error: 1.7721
# Epoch 76/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.8502 - y1_output_loss: 1.3554 - y2_output_loss: 3.4608 - y1_output_root_mean_squared_error: 1.1654 - y2_output_root_mean_squared_error: 1.8687 - val_loss: 6.2627 - val_y1_output_loss: 1.2841 - val_y2_output_loss: 5.2410 - val_y1_output_root_mean_squared_error: 1.1284 - val_y2_output_root_mean_squared_error: 2.2337
# Epoch 77/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.2950 - y1_output_loss: 1.5972 - y2_output_loss: 3.6603 - y1_output_root_mean_squared_error: 1.2683 - y2_output_root_mean_squared_error: 1.9200 - val_loss: 4.3888 - val_y1_output_loss: 1.5454 - val_y2_output_loss: 2.9772 - val_y1_output_root_mean_squared_error: 1.2376 - val_y2_output_root_mean_squared_error: 1.6903
# Epoch 78/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.7759 - y1_output_loss: 1.1460 - y2_output_loss: 2.6514 - y1_output_root_mean_squared_error: 1.0698 - y2_output_root_mean_squared_error: 1.6222 - val_loss: 4.2491 - val_y1_output_loss: 1.5913 - val_y2_output_loss: 2.7554 - val_y1_output_root_mean_squared_error: 1.2680 - val_y2_output_root_mean_squared_error: 1.6252
# Epoch 79/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.9605 - y1_output_loss: 1.3163 - y2_output_loss: 3.6582 - y1_output_root_mean_squared_error: 1.1417 - y2_output_root_mean_squared_error: 1.9123 - val_loss: 11.0725 - val_y1_output_loss: 4.7470 - val_y2_output_loss: 6.6231 - val_y1_output_root_mean_squared_error: 2.1641 - val_y2_output_root_mean_squared_error: 2.5277
# Epoch 80/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.0838 - y1_output_loss: 1.1958 - y2_output_loss: 2.8651 - y1_output_root_mean_squared_error: 1.0929 - y2_output_root_mean_squared_error: 1.6998 - val_loss: 3.7065 - val_y1_output_loss: 1.1774 - val_y2_output_loss: 2.6744 - val_y1_output_root_mean_squared_error: 1.0759 - val_y2_output_root_mean_squared_error: 1.5965
# Epoch 81/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.9263 - y1_output_loss: 1.1940 - y2_output_loss: 2.7292 - y1_output_root_mean_squared_error: 1.0943 - y2_output_root_mean_squared_error: 1.6519 - val_loss: 4.1324 - val_y1_output_loss: 1.2182 - val_y2_output_loss: 2.9705 - val_y1_output_root_mean_squared_error: 1.1113 - val_y2_output_root_mean_squared_error: 1.7021
# Epoch 82/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.3183 - y1_output_loss: 0.9790 - y2_output_loss: 2.3605 - y1_output_root_mean_squared_error: 0.9931 - y2_output_root_mean_squared_error: 1.5271 - val_loss: 3.5409 - val_y1_output_loss: 0.9023 - val_y2_output_loss: 2.7176 - val_y1_output_root_mean_squared_error: 0.9501 - val_y2_output_root_mean_squared_error: 1.6242
# Epoch 83/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.4099 - y1_output_loss: 1.2599 - y2_output_loss: 3.1228 - y1_output_root_mean_squared_error: 1.1261 - y2_output_root_mean_squared_error: 1.7725 - val_loss: 3.6314 - val_y1_output_loss: 1.2199 - val_y2_output_loss: 2.5454 - val_y1_output_root_mean_squared_error: 1.1014 - val_y2_output_root_mean_squared_error: 1.5551
# Epoch 84/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.5865 - y1_output_loss: 0.9962 - y2_output_loss: 2.6092 - y1_output_root_mean_squared_error: 0.9952 - y2_output_root_mean_squared_error: 1.6112 - val_loss: 3.2614 - val_y1_output_loss: 1.0054 - val_y2_output_loss: 2.4141 - val_y1_output_root_mean_squared_error: 0.9958 - val_y2_output_root_mean_squared_error: 1.5066
# Epoch 85/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.6963 - y1_output_loss: 1.2625 - y2_output_loss: 3.3936 - y1_output_root_mean_squared_error: 1.1280 - y2_output_root_mean_squared_error: 1.8504 - val_loss: 2.7099 - val_y1_output_loss: 0.8377 - val_y2_output_loss: 1.9721 - val_y1_output_root_mean_squared_error: 0.9148 - val_y2_output_root_mean_squared_error: 1.3686
# Epoch 86/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.6053 - y1_output_loss: 1.0904 - y2_output_loss: 2.5014 - y1_output_root_mean_squared_error: 1.0444 - y2_output_root_mean_squared_error: 1.5857 - val_loss: 4.0719 - val_y1_output_loss: 1.6640 - val_y2_output_loss: 2.5813 - val_y1_output_root_mean_squared_error: 1.2794 - val_y2_output_root_mean_squared_error: 1.5605
# Epoch 87/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.4681 - y1_output_loss: 1.0159 - y2_output_loss: 2.4279 - y1_output_root_mean_squared_error: 1.0100 - y2_output_root_mean_squared_error: 1.5646 - val_loss: 3.9300 - val_y1_output_loss: 1.4542 - val_y2_output_loss: 2.5655 - val_y1_output_root_mean_squared_error: 1.2090 - val_y2_output_root_mean_squared_error: 1.5711
# Epoch 88/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.4038 - y1_output_loss: 0.9220 - y2_output_loss: 2.5223 - y1_output_root_mean_squared_error: 0.9534 - y2_output_root_mean_squared_error: 1.5795 - val_loss: 10.9373 - val_y1_output_loss: 1.5722 - val_y2_output_loss: 9.5960 - val_y1_output_root_mean_squared_error: 1.2356 - val_y2_output_root_mean_squared_error: 3.0677
# Epoch 89/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.7501 - y1_output_loss: 1.2816 - y2_output_loss: 3.5198 - y1_output_root_mean_squared_error: 1.1337 - y2_output_root_mean_squared_error: 1.8614 - val_loss: 8.5777 - val_y1_output_loss: 1.6792 - val_y2_output_loss: 6.9845 - val_y1_output_root_mean_squared_error: 1.3139 - val_y2_output_root_mean_squared_error: 2.6175
# Epoch 90/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.9782 - y1_output_loss: 1.1262 - y2_output_loss: 2.8236 - y1_output_root_mean_squared_error: 1.0644 - y2_output_root_mean_squared_error: 1.6868 - val_loss: 3.8707 - val_y1_output_loss: 0.9791 - val_y2_output_loss: 2.9987 - val_y1_output_root_mean_squared_error: 0.9958 - val_y2_output_root_mean_squared_error: 1.6968
# Epoch 91/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.8611 - y1_output_loss: 0.7193 - y2_output_loss: 2.1310 - y1_output_root_mean_squared_error: 0.8516 - y2_output_root_mean_squared_error: 1.4614 - val_loss: 4.4316 - val_y1_output_loss: 1.1459 - val_y2_output_loss: 3.3421 - val_y1_output_root_mean_squared_error: 1.0848 - val_y2_output_root_mean_squared_error: 1.8041
# Epoch 92/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.3014 - y1_output_loss: 0.8705 - y2_output_loss: 2.4124 - y1_output_root_mean_squared_error: 0.9345 - y2_output_root_mean_squared_error: 1.5582 - val_loss: 3.8528 - val_y1_output_loss: 1.3118 - val_y2_output_loss: 2.6692 - val_y1_output_root_mean_squared_error: 1.1236 - val_y2_output_root_mean_squared_error: 1.6095
# Epoch 93/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.8953 - y1_output_loss: 0.8117 - y2_output_loss: 2.0743 - y1_output_root_mean_squared_error: 0.9040 - y2_output_root_mean_squared_error: 1.4416 - val_loss: 2.6154 - val_y1_output_loss: 0.8416 - val_y2_output_loss: 1.8170 - val_y1_output_root_mean_squared_error: 0.9276 - val_y2_output_root_mean_squared_error: 1.3247
# Epoch 94/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.4425 - y1_output_loss: 1.1373 - y2_output_loss: 3.3054 - y1_output_root_mean_squared_error: 1.0705 - y2_output_root_mean_squared_error: 1.8156 - val_loss: 6.5796 - val_y1_output_loss: 1.3816 - val_y2_output_loss: 5.4090 - val_y1_output_root_mean_squared_error: 1.1585 - val_y2_output_root_mean_squared_error: 2.2885
# Epoch 95/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.7205 - y1_output_loss: 0.6939 - y2_output_loss: 2.0068 - y1_output_root_mean_squared_error: 0.8352 - y2_output_root_mean_squared_error: 1.4223 - val_loss: 3.2085 - val_y1_output_loss: 0.8445 - val_y2_output_loss: 2.4090 - val_y1_output_root_mean_squared_error: 0.9300 - val_y2_output_root_mean_squared_error: 1.5309
# Epoch 96/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.0282 - y1_output_loss: 0.9561 - y2_output_loss: 2.2255 - y1_output_root_mean_squared_error: 0.9382 - y2_output_root_mean_squared_error: 1.4656 - val_loss: 10.9303 - val_y1_output_loss: 4.3877 - val_y2_output_loss: 6.4246 - val_y1_output_root_mean_squared_error: 2.1116 - val_y2_output_root_mean_squared_error: 2.5439
# Epoch 97/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.3307 - y1_output_loss: 0.9739 - y2_output_loss: 2.3521 - y1_output_root_mean_squared_error: 0.9901 - y2_output_root_mean_squared_error: 1.5331 - val_loss: 6.4019 - val_y1_output_loss: 1.8937 - val_y2_output_loss: 4.5572 - val_y1_output_root_mean_squared_error: 1.3917 - val_y2_output_root_mean_squared_error: 2.1131
# Epoch 98/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.1737 - y1_output_loss: 0.8502 - y2_output_loss: 2.3146 - y1_output_root_mean_squared_error: 0.9254 - y2_output_root_mean_squared_error: 1.5222 - val_loss: 4.2310 - val_y1_output_loss: 0.6792 - val_y2_output_loss: 3.6840 - val_y1_output_root_mean_squared_error: 0.8151 - val_y2_output_root_mean_squared_error: 1.8886
# Epoch 99/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.2825 - y1_output_loss: 0.8261 - y2_output_loss: 2.4461 - y1_output_root_mean_squared_error: 0.9084 - y2_output_root_mean_squared_error: 1.5676 - val_loss: 3.1115 - val_y1_output_loss: 0.8315 - val_y2_output_loss: 2.3564 - val_y1_output_root_mean_squared_error: 0.9056 - val_y2_output_root_mean_squared_error: 1.5138
# Epoch 100/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.7314 - y1_output_loss: 0.7455 - y2_output_loss: 1.9800 - y1_output_root_mean_squared_error: 0.8626 - y2_output_root_mean_squared_error: 1.4097 - val_loss: 3.4194 - val_y1_output_loss: 1.0764 - val_y2_output_loss: 2.3858 - val_y1_output_root_mean_squared_error: 1.0475 - val_y2_output_root_mean_squared_error: 1.5239
# Epoch 101/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.8348 - y1_output_loss: 0.6713 - y2_output_loss: 2.2458 - y1_output_root_mean_squared_error: 0.8172 - y2_output_root_mean_squared_error: 1.4721 - val_loss: 6.4091 - val_y1_output_loss: 1.8465 - val_y2_output_loss: 4.7091 - val_y1_output_root_mean_squared_error: 1.3569 - val_y2_output_root_mean_squared_error: 2.1373
# Epoch 102/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.4353 - y1_output_loss: 0.6804 - y2_output_loss: 1.7370 - y1_output_root_mean_squared_error: 0.8258 - y2_output_root_mean_squared_error: 1.3241 - val_loss: 2.2081 - val_y1_output_loss: 0.5963 - val_y2_output_loss: 1.6627 - val_y1_output_root_mean_squared_error: 0.7760 - val_y2_output_root_mean_squared_error: 1.2673
# Epoch 103/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.2825 - y1_output_loss: 0.5703 - y2_output_loss: 1.7215 - y1_output_root_mean_squared_error: 0.7577 - y2_output_root_mean_squared_error: 1.3071 - val_loss: 5.9657 - val_y1_output_loss: 0.6336 - val_y2_output_loss: 5.3900 - val_y1_output_root_mean_squared_error: 0.8007 - val_y2_output_root_mean_squared_error: 2.3075
# Epoch 104/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.8539 - y1_output_loss: 1.2723 - y2_output_loss: 3.5722 - y1_output_root_mean_squared_error: 1.1238 - y2_output_root_mean_squared_error: 1.8950 - val_loss: 3.2420 - val_y1_output_loss: 1.0392 - val_y2_output_loss: 2.3221 - val_y1_output_root_mean_squared_error: 0.9912 - val_y2_output_root_mean_squared_error: 1.5032
# Epoch 105/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.4226 - y1_output_loss: 0.6315 - y2_output_loss: 1.7869 - y1_output_root_mean_squared_error: 0.7967 - y2_output_root_mean_squared_error: 1.3371 - val_loss: 3.7981 - val_y1_output_loss: 0.7431 - val_y2_output_loss: 3.1612 - val_y1_output_root_mean_squared_error: 0.8472 - val_y2_output_root_mean_squared_error: 1.7551
# Epoch 106/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.4897 - y1_output_loss: 0.5885 - y2_output_loss: 1.9033 - y1_output_root_mean_squared_error: 0.7704 - y2_output_root_mean_squared_error: 1.3770 - val_loss: 4.7159 - val_y1_output_loss: 0.5636 - val_y2_output_loss: 4.2481 - val_y1_output_root_mean_squared_error: 0.7552 - val_y2_output_root_mean_squared_error: 2.0361
# Epoch 107/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.5787 - y1_output_loss: 0.9607 - y2_output_loss: 2.6239 - y1_output_root_mean_squared_error: 0.9788 - y2_output_root_mean_squared_error: 1.6188 - val_loss: 1.9795 - val_y1_output_loss: 0.5347 - val_y2_output_loss: 1.4718 - val_y1_output_root_mean_squared_error: 0.7401 - val_y2_output_root_mean_squared_error: 1.1966
# Epoch 108/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.2158 - y1_output_loss: 0.6006 - y2_output_loss: 1.6165 - y1_output_root_mean_squared_error: 0.7740 - y2_output_root_mean_squared_error: 1.2715 - val_loss: 2.6798 - val_y1_output_loss: 0.6157 - val_y2_output_loss: 2.0951 - val_y1_output_root_mean_squared_error: 0.7972 - val_y2_output_root_mean_squared_error: 1.4298
# Epoch 109/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.8577 - y1_output_loss: 1.2097 - y2_output_loss: 2.8681 - y1_output_root_mean_squared_error: 1.0669 - y2_output_root_mean_squared_error: 1.6491 - val_loss: 5.5280 - val_y1_output_loss: 2.1014 - val_y2_output_loss: 3.6292 - val_y1_output_root_mean_squared_error: 1.4431 - val_y2_output_root_mean_squared_error: 1.8562
# Epoch 110/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.8759 - y1_output_loss: 0.7676 - y2_output_loss: 2.0845 - y1_output_root_mean_squared_error: 0.8802 - y2_output_root_mean_squared_error: 1.4495 - val_loss: 4.6714 - val_y1_output_loss: 1.1757 - val_y2_output_loss: 3.6121 - val_y1_output_root_mean_squared_error: 1.0923 - val_y2_output_root_mean_squared_error: 1.8650
# Epoch 111/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.4433 - y1_output_loss: 0.9523 - y2_output_loss: 2.4620 - y1_output_root_mean_squared_error: 0.9798 - y2_output_root_mean_squared_error: 1.5758 - val_loss: 2.2387 - val_y1_output_loss: 0.5769 - val_y2_output_loss: 1.6869 - val_y1_output_root_mean_squared_error: 0.7722 - val_y2_output_root_mean_squared_error: 1.2816
# Epoch 112/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.0264 - y1_output_loss: 0.6983 - y2_output_loss: 2.3225 - y1_output_root_mean_squared_error: 0.8387 - y2_output_root_mean_squared_error: 1.5242 - val_loss: 3.6804 - val_y1_output_loss: 0.4389 - val_y2_output_loss: 3.3223 - val_y1_output_root_mean_squared_error: 0.6667 - val_y2_output_root_mean_squared_error: 1.7988
# Epoch 113/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.4139 - y1_output_loss: 0.5246 - y2_output_loss: 1.8857 - y1_output_root_mean_squared_error: 0.7262 - y2_output_root_mean_squared_error: 1.3735 - val_loss: 2.8068 - val_y1_output_loss: 0.8288 - val_y2_output_loss: 1.9969 - val_y1_output_root_mean_squared_error: 0.9232 - val_y2_output_root_mean_squared_error: 1.3980
# Epoch 114/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.9482 - y1_output_loss: 0.7021 - y2_output_loss: 2.2347 - y1_output_root_mean_squared_error: 0.8391 - y2_output_root_mean_squared_error: 1.4980 - val_loss: 4.2724 - val_y1_output_loss: 1.5636 - val_y2_output_loss: 2.9092 - val_y1_output_root_mean_squared_error: 1.2165 - val_y2_output_root_mean_squared_error: 1.6711
# Epoch 115/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.5243 - y1_output_loss: 0.6602 - y2_output_loss: 1.8673 - y1_output_root_mean_squared_error: 0.8112 - y2_output_root_mean_squared_error: 1.3661 - val_loss: 3.5426 - val_y1_output_loss: 1.3701 - val_y2_output_loss: 2.2287 - val_y1_output_root_mean_squared_error: 1.1679 - val_y2_output_root_mean_squared_error: 1.4760
# Epoch 116/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.5860 - y1_output_loss: 0.6165 - y2_output_loss: 1.9541 - y1_output_root_mean_squared_error: 0.7871 - y2_output_root_mean_squared_error: 1.4023 - val_loss: 1.9714 - val_y1_output_loss: 0.5525 - val_y2_output_loss: 1.4465 - val_y1_output_root_mean_squared_error: 0.7516 - val_y2_output_root_mean_squared_error: 1.1860
# Epoch 117/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.0311 - y1_output_loss: 0.7175 - y2_output_loss: 2.2869 - y1_output_root_mean_squared_error: 0.8504 - y2_output_root_mean_squared_error: 1.5192 - val_loss: 1.8940 - val_y1_output_loss: 0.5923 - val_y2_output_loss: 1.3345 - val_y1_output_root_mean_squared_error: 0.7800 - val_y2_output_root_mean_squared_error: 1.1339
# Epoch 118/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.2784 - y1_output_loss: 0.5693 - y2_output_loss: 1.6960 - y1_output_root_mean_squared_error: 0.7538 - y2_output_root_mean_squared_error: 1.3077 - val_loss: 2.4200 - val_y1_output_loss: 0.6650 - val_y2_output_loss: 1.7833 - val_y1_output_root_mean_squared_error: 0.8251 - val_y2_output_root_mean_squared_error: 1.3188
# Epoch 119/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.5538 - y1_output_loss: 0.5827 - y2_output_loss: 2.0043 - y1_output_root_mean_squared_error: 0.7355 - y2_output_root_mean_squared_error: 1.4187 - val_loss: 3.2168 - val_y1_output_loss: 1.0733 - val_y2_output_loss: 2.2796 - val_y1_output_root_mean_squared_error: 1.0203 - val_y2_output_root_mean_squared_error: 1.4751
# Epoch 120/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.0270 - y1_output_loss: 0.5385 - y2_output_loss: 1.4865 - y1_output_root_mean_squared_error: 0.7324 - y2_output_root_mean_squared_error: 1.2209 - val_loss: 2.1181 - val_y1_output_loss: 0.4811 - val_y2_output_loss: 1.6741 - val_y1_output_root_mean_squared_error: 0.6974 - val_y2_output_root_mean_squared_error: 1.2774
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4060 - y1_output_loss: 0.1152 - y2_output_loss: 0.2893 - y1_output_root_mean_squared_error: 0.3396 - y2_output_root_mean_squared_error: 0.5392 - val_loss: 0.9657 - val_y1_output_loss: 0.2103 - val_y2_output_loss: 0.7596 - val_y1_output_root_mean_squared_error: 0.4629 - val_y2_output_root_mean_squared_error: 0.8668
# Epoch 462/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3761 - y1_output_loss: 0.1114 - y2_output_loss: 0.2664 - y1_output_root_mean_squared_error: 0.3336 - y2_output_root_mean_squared_error: 0.5147 - val_loss: 0.7142 - val_y1_output_loss: 0.2091 - val_y2_output_loss: 0.4968 - val_y1_output_root_mean_squared_error: 0.4604 - val_y2_output_root_mean_squared_error: 0.7087
# Epoch 463/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3301 - y1_output_loss: 0.1162 - y2_output_loss: 0.2123 - y1_output_root_mean_squared_error: 0.3413 - y2_output_root_mean_squared_error: 0.4622 - val_loss: 0.7649 - val_y1_output_loss: 0.2218 - val_y2_output_loss: 0.5277 - val_y1_output_root_mean_squared_error: 0.4781 - val_y2_output_root_mean_squared_error: 0.7323
# Epoch 464/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5826 - y1_output_loss: 0.1846 - y2_output_loss: 0.3947 - y1_output_root_mean_squared_error: 0.4298 - y2_output_root_mean_squared_error: 0.6308 - val_loss: 1.0551 - val_y1_output_loss: 0.1906 - val_y2_output_loss: 0.8679 - val_y1_output_root_mean_squared_error: 0.4408 - val_y2_output_root_mean_squared_error: 0.9278
# Epoch 465/500
# 614/614 [==============================] - 0s 164us/sample - loss: 0.4625 - y1_output_loss: 0.1322 - y2_output_loss: 0.3265 - y1_output_root_mean_squared_error: 0.3652 - y2_output_root_mean_squared_error: 0.5737 - val_loss: 0.8379 - val_y1_output_loss: 0.2046 - val_y2_output_loss: 0.6260 - val_y1_output_root_mean_squared_error: 0.4527 - val_y2_output_root_mean_squared_error: 0.7956
# Epoch 466/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.7375 - y1_output_loss: 0.1811 - y2_output_loss: 0.5513 - y1_output_root_mean_squared_error: 0.4265 - y2_output_root_mean_squared_error: 0.7454 - val_loss: 0.7656 - val_y1_output_loss: 0.2093 - val_y2_output_loss: 0.5405 - val_y1_output_root_mean_squared_error: 0.4640 - val_y2_output_root_mean_squared_error: 0.7418
# Epoch 467/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4515 - y1_output_loss: 0.1402 - y2_output_loss: 0.3155 - y1_output_root_mean_squared_error: 0.3725 - y2_output_root_mean_squared_error: 0.5592 - val_loss: 1.1423 - val_y1_output_loss: 0.4896 - val_y2_output_loss: 0.6386 - val_y1_output_root_mean_squared_error: 0.7094 - val_y2_output_root_mean_squared_error: 0.7994
# Epoch 468/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.5189 - y1_output_loss: 0.1493 - y2_output_loss: 0.3696 - y1_output_root_mean_squared_error: 0.3850 - y2_output_root_mean_squared_error: 0.6089 - val_loss: 1.3082 - val_y1_output_loss: 0.3333 - val_y2_output_loss: 0.9973 - val_y1_output_root_mean_squared_error: 0.5649 - val_y2_output_root_mean_squared_error: 0.9946
# Epoch 469/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3865 - y1_output_loss: 0.1207 - y2_output_loss: 0.2638 - y1_output_root_mean_squared_error: 0.3477 - y2_output_root_mean_squared_error: 0.5154 - val_loss: 0.8109 - val_y1_output_loss: 0.2324 - val_y2_output_loss: 0.5940 - val_y1_output_root_mean_squared_error: 0.4746 - val_y2_output_root_mean_squared_error: 0.7653
# Epoch 470/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4115 - y1_output_loss: 0.1161 - y2_output_loss: 0.2928 - y1_output_root_mean_squared_error: 0.3412 - y2_output_root_mean_squared_error: 0.5432 - val_loss: 0.7793 - val_y1_output_loss: 0.2273 - val_y2_output_loss: 0.5448 - val_y1_output_root_mean_squared_error: 0.4841 - val_y2_output_root_mean_squared_error: 0.7382
# Epoch 471/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3256 - y1_output_loss: 0.1122 - y2_output_loss: 0.2160 - y1_output_root_mean_squared_error: 0.3348 - y2_output_root_mean_squared_error: 0.4620 - val_loss: 0.9456 - val_y1_output_loss: 0.4333 - val_y2_output_loss: 0.5483 - val_y1_output_root_mean_squared_error: 0.6332 - val_y2_output_root_mean_squared_error: 0.7380
# Epoch 472/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3392 - y1_output_loss: 0.1172 - y2_output_loss: 0.2206 - y1_output_root_mean_squared_error: 0.3438 - y2_output_root_mean_squared_error: 0.4701 - val_loss: 0.7280 - val_y1_output_loss: 0.2000 - val_y2_output_loss: 0.5133 - val_y1_output_root_mean_squared_error: 0.4518 - val_y2_output_root_mean_squared_error: 0.7238
# Epoch 473/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3315 - y1_output_loss: 0.1103 - y2_output_loss: 0.2186 - y1_output_root_mean_squared_error: 0.3332 - y2_output_root_mean_squared_error: 0.4695 - val_loss: 0.6705 - val_y1_output_loss: 0.2065 - val_y2_output_loss: 0.4584 - val_y1_output_root_mean_squared_error: 0.4554 - val_y2_output_root_mean_squared_error: 0.6806
# Epoch 474/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3969 - y1_output_loss: 0.1329 - y2_output_loss: 0.2613 - y1_output_root_mean_squared_error: 0.3658 - y2_output_root_mean_squared_error: 0.5130 - val_loss: 0.7602 - val_y1_output_loss: 0.2074 - val_y2_output_loss: 0.5437 - val_y1_output_root_mean_squared_error: 0.4592 - val_y2_output_root_mean_squared_error: 0.7412
# Epoch 475/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3596 - y1_output_loss: 0.1090 - y2_output_loss: 0.2509 - y1_output_root_mean_squared_error: 0.3296 - y2_output_root_mean_squared_error: 0.5010 - val_loss: 0.9647 - val_y1_output_loss: 0.2246 - val_y2_output_loss: 0.7585 - val_y1_output_root_mean_squared_error: 0.4767 - val_y2_output_root_mean_squared_error: 0.8587
# Epoch 476/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3589 - y1_output_loss: 0.1207 - y2_output_loss: 0.2366 - y1_output_root_mean_squared_error: 0.3476 - y2_output_root_mean_squared_error: 0.4879 - val_loss: 0.7906 - val_y1_output_loss: 0.2644 - val_y2_output_loss: 0.5057 - val_y1_output_root_mean_squared_error: 0.5235 - val_y2_output_root_mean_squared_error: 0.7187
# Epoch 477/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4314 - y1_output_loss: 0.1391 - y2_output_loss: 0.2888 - y1_output_root_mean_squared_error: 0.3742 - y2_output_root_mean_squared_error: 0.5398 - val_loss: 0.7342 - val_y1_output_loss: 0.2097 - val_y2_output_loss: 0.5179 - val_y1_output_root_mean_squared_error: 0.4574 - val_y2_output_root_mean_squared_error: 0.7245
# Epoch 478/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.2974 - y1_output_loss: 0.0998 - y2_output_loss: 0.1974 - y1_output_root_mean_squared_error: 0.3159 - y2_output_root_mean_squared_error: 0.4445 - val_loss: 1.4712 - val_y1_output_loss: 0.3237 - val_y2_output_loss: 1.1642 - val_y1_output_root_mean_squared_error: 0.5581 - val_y2_output_root_mean_squared_error: 1.0769
# Epoch 479/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3566 - y1_output_loss: 0.1114 - y2_output_loss: 0.2438 - y1_output_root_mean_squared_error: 0.3347 - y2_output_root_mean_squared_error: 0.4946 - val_loss: 0.7405 - val_y1_output_loss: 0.1883 - val_y2_output_loss: 0.5469 - val_y1_output_root_mean_squared_error: 0.4371 - val_y2_output_root_mean_squared_error: 0.7412
# Epoch 480/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3770 - y1_output_loss: 0.1088 - y2_output_loss: 0.2661 - y1_output_root_mean_squared_error: 0.3296 - y2_output_root_mean_squared_error: 0.5180 - val_loss: 0.8274 - val_y1_output_loss: 0.2109 - val_y2_output_loss: 0.6190 - val_y1_output_root_mean_squared_error: 0.4603 - val_y2_output_root_mean_squared_error: 0.7845
# Epoch 481/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3017 - y1_output_loss: 0.1058 - y2_output_loss: 0.1976 - y1_output_root_mean_squared_error: 0.3232 - y2_output_root_mean_squared_error: 0.4441 - val_loss: 0.9036 - val_y1_output_loss: 0.1910 - val_y2_output_loss: 0.7227 - val_y1_output_root_mean_squared_error: 0.4344 - val_y2_output_root_mean_squared_error: 0.8455
# Epoch 482/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2750 - y1_output_loss: 0.1003 - y2_output_loss: 0.1737 - y1_output_root_mean_squared_error: 0.3166 - y2_output_root_mean_squared_error: 0.4181 - val_loss: 0.8007 - val_y1_output_loss: 0.2705 - val_y2_output_loss: 0.5171 - val_y1_output_root_mean_squared_error: 0.5281 - val_y2_output_root_mean_squared_error: 0.7224
# Epoch 483/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3907 - y1_output_loss: 0.1312 - y2_output_loss: 0.2580 - y1_output_root_mean_squared_error: 0.3619 - y2_output_root_mean_squared_error: 0.5096 - val_loss: 0.8724 - val_y1_output_loss: 0.2347 - val_y2_output_loss: 0.6523 - val_y1_output_root_mean_squared_error: 0.4749 - val_y2_output_root_mean_squared_error: 0.8043
# Epoch 484/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3269 - y1_output_loss: 0.1065 - y2_output_loss: 0.2403 - y1_output_root_mean_squared_error: 0.3213 - y2_output_root_mean_squared_error: 0.4730 - val_loss: 2.7658 - val_y1_output_loss: 0.5266 - val_y2_output_loss: 2.2919 - val_y1_output_root_mean_squared_error: 0.7088 - val_y2_output_root_mean_squared_error: 1.5045
# Epoch 485/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3788 - y1_output_loss: 0.1103 - y2_output_loss: 0.2697 - y1_output_root_mean_squared_error: 0.3324 - y2_output_root_mean_squared_error: 0.5180 - val_loss: 0.9910 - val_y1_output_loss: 0.2329 - val_y2_output_loss: 0.7801 - val_y1_output_root_mean_squared_error: 0.4743 - val_y2_output_root_mean_squared_error: 0.8752
# Epoch 486/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4052 - y1_output_loss: 0.1410 - y2_output_loss: 0.2618 - y1_output_root_mean_squared_error: 0.3764 - y2_output_root_mean_squared_error: 0.5133 - val_loss: 0.7535 - val_y1_output_loss: 0.2316 - val_y2_output_loss: 0.5063 - val_y1_output_root_mean_squared_error: 0.4891 - val_y2_output_root_mean_squared_error: 0.7171
# Epoch 487/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.2688 - y1_output_loss: 0.0984 - y2_output_loss: 0.1728 - y1_output_root_mean_squared_error: 0.3132 - y2_output_root_mean_squared_error: 0.4132 - val_loss: 1.2965 - val_y1_output_loss: 0.3819 - val_y2_output_loss: 0.9111 - val_y1_output_root_mean_squared_error: 0.6255 - val_y2_output_root_mean_squared_error: 0.9514
# Epoch 488/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3331 - y1_output_loss: 0.1047 - y2_output_loss: 0.2258 - y1_output_root_mean_squared_error: 0.3249 - y2_output_root_mean_squared_error: 0.4770 - val_loss: 0.7965 - val_y1_output_loss: 0.2580 - val_y2_output_loss: 0.5203 - val_y1_output_root_mean_squared_error: 0.5169 - val_y2_output_root_mean_squared_error: 0.7275
# Epoch 489/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3219 - y1_output_loss: 0.1071 - y2_output_loss: 0.2132 - y1_output_root_mean_squared_error: 0.3282 - y2_output_root_mean_squared_error: 0.4628 - val_loss: 0.9508 - val_y1_output_loss: 0.2729 - val_y2_output_loss: 0.6871 - val_y1_output_root_mean_squared_error: 0.5125 - val_y2_output_root_mean_squared_error: 0.8296
# Epoch 490/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3207 - y1_output_loss: 0.1015 - y2_output_loss: 0.2183 - y1_output_root_mean_squared_error: 0.3185 - y2_output_root_mean_squared_error: 0.4683 - val_loss: 0.9488 - val_y1_output_loss: 0.2328 - val_y2_output_loss: 0.7167 - val_y1_output_root_mean_squared_error: 0.4794 - val_y2_output_root_mean_squared_error: 0.8479
# Epoch 491/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3725 - y1_output_loss: 0.1111 - y2_output_loss: 0.2601 - y1_output_root_mean_squared_error: 0.3345 - y2_output_root_mean_squared_error: 0.5105 - val_loss: 0.8413 - val_y1_output_loss: 0.2084 - val_y2_output_loss: 0.6255 - val_y1_output_root_mean_squared_error: 0.4622 - val_y2_output_root_mean_squared_error: 0.7922
# Epoch 492/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.2659 - y1_output_loss: 0.0986 - y2_output_loss: 0.1664 - y1_output_root_mean_squared_error: 0.3147 - y2_output_root_mean_squared_error: 0.4085 - val_loss: 0.6838 - val_y1_output_loss: 0.1928 - val_y2_output_loss: 0.4864 - val_y1_output_root_mean_squared_error: 0.4408 - val_y2_output_root_mean_squared_error: 0.6997
# Epoch 493/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3047 - y1_output_loss: 0.1074 - y2_output_loss: 0.1953 - y1_output_root_mean_squared_error: 0.3288 - y2_output_root_mean_squared_error: 0.4434 - val_loss: 0.6852 - val_y1_output_loss: 0.1878 - val_y2_output_loss: 0.4998 - val_y1_output_root_mean_squared_error: 0.4345 - val_y2_output_root_mean_squared_error: 0.7045
# Epoch 494/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.2480 - y1_output_loss: 0.0946 - y2_output_loss: 0.1526 - y1_output_root_mean_squared_error: 0.3083 - y2_output_root_mean_squared_error: 0.3911 - val_loss: 0.6906 - val_y1_output_loss: 0.1945 - val_y2_output_loss: 0.4915 - val_y1_output_root_mean_squared_error: 0.4449 - val_y2_output_root_mean_squared_error: 0.7019
# Epoch 495/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.2985 - y1_output_loss: 0.0958 - y2_output_loss: 0.2025 - y1_output_root_mean_squared_error: 0.3089 - y2_output_root_mean_squared_error: 0.4506 - val_loss: 0.9044 - val_y1_output_loss: 0.2426 - val_y2_output_loss: 0.6440 - val_y1_output_root_mean_squared_error: 0.5012 - val_y2_output_root_mean_squared_error: 0.8082
# Epoch 496/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3111 - y1_output_loss: 0.1026 - y2_output_loss: 0.2083 - y1_output_root_mean_squared_error: 0.3207 - y2_output_root_mean_squared_error: 0.4563 - val_loss: 0.8192 - val_y1_output_loss: 0.2045 - val_y2_output_loss: 0.6222 - val_y1_output_root_mean_squared_error: 0.4473 - val_y2_output_root_mean_squared_error: 0.7869
# Epoch 497/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3423 - y1_output_loss: 0.1116 - y2_output_loss: 0.2292 - y1_output_root_mean_squared_error: 0.3347 - y2_output_root_mean_squared_error: 0.4798 - val_loss: 0.7273 - val_y1_output_loss: 0.2430 - val_y2_output_loss: 0.4748 - val_y1_output_root_mean_squared_error: 0.4964 - val_y2_output_root_mean_squared_error: 0.6934
# Epoch 498/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.2587 - y1_output_loss: 0.0965 - y2_output_loss: 0.1619 - y1_output_root_mean_squared_error: 0.3111 - y2_output_root_mean_squared_error: 0.4025 - val_loss: 0.7687 - val_y1_output_loss: 0.1975 - val_y2_output_loss: 0.5783 - val_y1_output_root_mean_squared_error: 0.4435 - val_y2_output_root_mean_squared_error: 0.7563
# Epoch 499/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4982 - y1_output_loss: 0.1430 - y2_output_loss: 0.3541 - y1_output_root_mean_squared_error: 0.3774 - y2_output_root_mean_squared_error: 0.5964 - val_loss: 0.9139 - val_y1_output_loss: 0.2517 - val_y2_output_loss: 0.6643 - val_y1_output_root_mean_squared_error: 0.4998 - val_y2_output_root_mean_squared_error: 0.8149
# Epoch 500/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3497 - y1_output_loss: 0.1195 - y2_output_loss: 0.2288 - y1_output_root_mean_squared_error: 0.3470 - y2_output_root_mean_squared_error: 0.4789 - val_loss: 0.7573 - val_y1_output_loss: 0.2127 - val_y2_output_loss: 0.5362 - val_y1_output_root_mean_squared_error: 0.4678 - val_y2_output_root_mean_squared_error: 0.7338

# %%
model.evaluate(x=norm_test_X, y=test_Y)
# Out:
# 154/154 [==============================] - 0s 37us/sample - loss: 0.7573 - y1_output_loss: 0.2137 - y2_output_loss: 0.5312 - y1_output_root_mean_squared_error: 0.4678 - y2_output_root_mean_squared_error: 0.7338
# [0.7573224642834107, 0.21370962, 0.53120077, 0.46780387, 0.73381335]

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 38us/sample - loss: 0.7573 - y1_output_loss: 0.2137 - y2_output_loss: 0.5312 - y1_output_root_mean_squared_error: 0.4678 - y2_output_root_mean_squared_error: 0.7338
# Loss = 0.7573224642834107, Y1_loss = 0.21370962262153625, Y1_mse = 0.46780386567115784, Y2_loss = 0.5312007665634155, Y2_mse = 0.7338133454322815

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
